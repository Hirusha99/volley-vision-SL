# %%
from packages.split_images import *

# %%
video_to_frames("videos/AlphaGo Official Trailer.mp4",
                "output/video", frame_interval=30)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\HIRUSHA\AppData\Local\Temp\ipykernel_4800\3906883268.py:1: SyntaxWarning: invalid escape sequence '\A'
#   video_to_frames("videos\AlphaGo Official Trailer.mp4", "output\video", frame_interval=30)
# C:\Users\HIRUSHA\AppData\Local\Temp\ipykernel_4800\3906883268.py:1: SyntaxWarning: invalid escape sequence '\A'
#   video_to_frames("videos\AlphaGo Official Trailer.mp4", "output\video", frame_interval=30)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 video_to_frames("videos\AlphaGo Official Trailer.mp4", "output\video", frame_interval=30)
#
# File d:\HIRU\Mphil\Implementation-volley\packages\split_images.py:7, in video_to_frames(video_path, output_folder, frame_interval)
# ...
